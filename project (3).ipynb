# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# !pip install torch numpy pandas scipy scikit-learn timm transformers h5py

# %%
# %cd /content/drive/MyDrive/vision_language_project/Surgical-VQLA
# Out:
# /content/drive/MyDrive/vision_language_project/Surgical-VQLA

# %%
import os

# Change to the directory where your project is stored
os.chdir('/content/drive/MyDrive/vision_language_project/Surgical-VQLA')

# Verify the change
print(f"Current directory: {os.getcwd()}")
# Out:
# Current directory: /content/drive/MyDrive/vision_language_project/Surgical-VQLA

# %%
# !pip install torch torchvision transformers h5py tqdm

# %%
# !pip install wget

# %%
# !python /content/drive/MyDrive/vision_and_language_project/Surgical-VQLA/dataset/feature_extraction/feature_extraction_EndoVis18-VQLA-frcnn.py

# %%
# !python /content/drive/MyDrive/vision_and_language_project/Surgical-VQLA/dataset/feature_extraction/feature_extraction_EndoVis18-VQLA-resnet.py

# %%
# !python /content/drive/MyDrive/vision_and_language_project/Surgical-VQLA/dataset/feature_extraction/feature_extraction_EndoVis18-VQLA-frcnn.py

# %%
# !python /content/drive/MyDrive/vision_and_language_project/Surgical-VQLA/dataset/feature_extraction/feature_extraction_EndoVis18-VQLA-resnet.py

# %%
import torch
torch.cuda.empty_cache()

# %%
import os

# Define the path to the directory
checkpoint_dir = "/content/drive/MyDrive/checkpoints/lvit/"

# Create the directory if it doesn't exist
if not os.path.exists(checkpoint_dir):
    os.makedirs(checkpoint_dir)
    print(f"Created directory: {checkpoint_dir}")
else:
    print(f"Directory already exists: {checkpoint_dir}")
# Out:
# Directory already exists: /content/drive/MyDrive/checkpoints/lvit/

# %%
import os

# Change to the directory where your project is stored
os.chdir('/content/drive/MyDrive/vision_language_project')

# Verify the change
print(f"Current directory: {os.getcwd()}")
# Out:
# Current directory: /content/drive/MyDrive/vision_language_project

# %%
import glob
train_seq = [2, 3, 4, 6, 7, 9, 10, 11, 12, 14, 15]
folder_head = '/content/drive/MyDrive/vision_language_project/Surgical-VQLA/dataset/EndoVis-18-VQLA/seq_'
folder_tail = '/vqla/*.txt'
filenames = []
for seq in train_seq:
    filenames += glob.glob(folder_head + str(seq) + folder_tail)
print(f"Found {len(filenames)} files")
# Out:
# Found 1564 files

# %%
# !ls -l /content/drive/MyDrive/checkpoints/lvit/
# Out:
# total 3228405
# -rw------- 1 root root 3305886341 Dec 13 01:05 Best.pth

# %%
import os

checkpoint_dir = '/content/drive/MyDrive/checkpoints/lvit/'
os.makedirs(checkpoint_dir, exist_ok=True)  # Ensure the directory exists

checkpoint_path = os.path.join(checkpoint_dir, 'Best.pth')
print(f"Checkpoint Path: {checkpoint_path}")
# Out:
# Checkpoint Path: /content/drive/MyDrive/checkpoints/lvit/Best.pth

# %%
# !python /content/drive/MyDrive/vision_language_project/Surgical-VQLA/train.py --checkpoint_dir /content/drive/MyDrive/checkpoints/lvit/ --transformer_ver lvit --batch_size 8 --epochs 80 #make epochs greater 1 here
# Out:
# Streaming output truncated to the last 5000 lines.
# Processing batch 440/1129
# Processing batch 450/1129
# Processing batch 460/1129
# Processing batch 470/1129
# Processing batch 480/1129
# Processing batch 490/1129
# Processing batch 500/1129
# Processing batch 510/1129
# Processing batch 520/1129
# Processing batch 530/1129
# Processing batch 540/1129
# Processing batch 550/1129
# Processing batch 560/1129
# Processing batch 570/1129
# Processing batch 580/1129
# Processing batch 590/1129
# Processing batch 600/1129
# Processing batch 610/1129
# Processing batch 620/1129
# Processing batch 630/1129
# Processing batch 640/1129
# Processing batch 650/1129
# Processing batch 660/1129
# Processing batch 670/1129
# Processing batch 680/1129
# Processing batch 690/1129
# Processing batch 700/1129
# Processing batch 710/1129
# Processing batch 720/1129
# Processing batch 730/1129
# Processing batch 740/1129
# Processing batch 750/1129
# Processing batch 760/1129
# ...

# %%
# !fuser /content/drive/MyDrive/checkpoints/lvit/Best.pth

# %%
import os
os.environ['TF_ENABLE_ONEDNN_OPTS'] = '0'

# %%
# !sudo apt-get install -y tensorrt
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tensorrt is already the newest version (10.7.0.23-1+cuda12.6).
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.

# %%
# !python /content/drive/MyDrive/vision_language_project/Surgical-VQLA/train.py --validate True --checkpoint_dir /content/drive/MyDrive/checkpoints/lvit/ --batch_size 8
# Out:
# 2024-12-13 02:55:41.803679: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-13 02:55:41.824880: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-13 02:55:41.831436: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-13 02:55:41.846883: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !ls /content/drive/MyDrive/checkpoints/lvit/
# Out:
# Best.pth
